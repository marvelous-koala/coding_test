# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys

# %%
sys.stdin = open("/content/drive/MyDrive/Jupyter/Coding_test/coding_test/sample_input.txt", "r")
nums = int(sys.stdin.readline())
nums
# Out:
# 3

# %%
for k in nums():
    sqr = int(sys.stdin.readline())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-7ca632370d66> in <module>()
# ----> 1 T = int(sys.stdin.readline())
#       2 print(T)
#
# ValueError: invalid literal for int() with base 10: '0 0 1 0 0 0 0\n'

# %%
input()
# Out:
# 5
# '5'
